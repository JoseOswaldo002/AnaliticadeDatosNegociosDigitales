# %% [markdown]
# # 🧪 Prácticas por Dataset de Kaggle

# %% [markdown]
# | Tipo de conversión      | Comando Pandas          | Ejemplo                                                 | ¿Qué hace?                                                                 |
# | ----------------------- | ----------------------- | ------------------------------------------------------- | -------------------------------------------------------------------------- |
# | Texto a fecha           | `pd.to_datetime()`      | `df['Fecha'] = pd.to_datetime(df['Fecha'])`             | Convierte strings como `'2022-01-01'` a formato datetime                   |
# | Texto a número          | `pd.to_numeric()`       | `df['Col'] = pd.to_numeric(df['Col'], errors='coerce')` | Convierte texto como `'123'` a número; si falla, pone `NaN` (con `coerce`) |
# | Texto a categoría       | `.astype('category')`   | `df['Tipo'] = df['Tipo'].astype('category')`            | Convierte texto repetido en categorías, ahorra memoria                     |
# | Texto a número entero   | `.astype('int')`        | `df['Año'] = df['Año'].astype('int')`                   | Convierte valores a enteros (falla si hay `NaN`)                           |
# | Texto a decimal (float) | `.astype('float')`      | `df['Precio'] = df['Precio'].astype('float')`           | Convierte a número decimal                                                 |
# | Número a texto          | `.astype('str')`        | `df['ID'] = df['ID'].astype('str')`                     | Convierte números a texto                                                  |
# | Fecha a texto           | `.dt.strftime('%Y-%m')` | `df['FechaTexto'] = df['Fecha'].dt.strftime('%Y-%m')`   | Convierte datetime a string con formato personalizado                      |
# | Extraer año de fecha    | `.dt.year`              | `df['Año'] = df['Fecha'].dt.year`                       | Obtiene el año de una columna datetime                                     |
# | Extraer mes de fecha    | `.dt.month`             | `df['Mes'] = df['Fecha'].dt.month`                      | Obtiene el número de mes (1 a 12)                                          |
# | Extraer día de fecha    | `.dt.day`               | `df['Día'] = df['Fecha'].dt.day`                        | Extrae el día del mes                                                      |
# | Extraer nombre del mes  | `.dt.month_name()`      | `df['MesNombre'] = df['Fecha'].dt.month_name()`         | Extrae el nombre del mes (`January`, `February`, etc.)                     |
# | Extraer día de semana   | `.dt.weekday`           | `df['Semana'] = df['Fecha'].dt.weekday`                 | Devuelve 0 (lunes) a 6 (domingo)                                           |
# | Redondear decimales     | `.round(n)`             | `df['Precio'] = df['Precio'].round(2)`                  | Redondea a `n` decimales                                                   |
# | Reemplazar valores      | `.replace()`            | `df['Col'].replace('-', np.nan, inplace=True)`          | Reemplaza valores (como `"-"` por `NaN`)                                   |
# | Quitar símbolos/texto   | `.str.replace()`        | `df['Precio'] = df['Precio'].str.replace('$', '')`      | Quita o cambia texto específico                                            |

# %% [markdown]
# ## 🛍️ Retail Sales Dataset

# %% [markdown]
# 🔗 Dataset disponible en: [https://www.kaggle.com/datasets/mohammadtalib786/retail-sales-dataset?utm_source=chatgpt.com](https://www.kaggle.com/datasets/mohammadtalib786/retail-sales-dataset?utm_source=chatgpt.com)

# %%
# Importat pandas
import pandas as pd

# %%
# Cargar el DataSets
df_retail = pd.read_csv('./DataSets/retail_sales_dataset.csv')
df_retail.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %% [markdown]
# **Pregunta:** ¿Cuántas filas y columnas tiene el dataset?

# %%
# Tu código aquí
df_retail.shape
# Out:
# (1000, 9)

# %% [markdown]
# **Pregunta:** ¿Cuáles son los tipos de datos de cada columna?

# %%
# Tu código aquí
df_retail.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %% [markdown]
# **Pregunta:** ¿Qué productos tienen mayores ventas en cantidad?

# %%
# Tu código aquí
df_retail.groupby('Product Category')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product Category
# Clothing       894
# Electronics    849
# Beauty         771
# Name: Quantity, dtype: int64

# %% [markdown]
# ### Añadir columna de tienda a los 1000 registros

# %%
import numpy as np

# Lista de nombres de tiendas ficticias
stores = ['Tienda Norte', 'Tienda Sur', 'Tienda Este', 'Tienda Oeste']

# Asignar aleatoriamente a cada fila
df_retail['Store'] = np.random.choice(stores, size=len(df_retail))

# %%
df_retail.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount         Store
# 0         3              50           150  Tienda Norte
# 1         2             500          1000  Tienda Oeste
# 2         1              30            30  Tienda Oeste
# 3         1             500           500  Tienda Oeste
# 4         2              50           100  Tienda Oeste

# %% [markdown]
# **Pregunta:** ¿Qué tiendas venden más productos?

# %%
# Tu código aquí
df_retail.groupby('Store')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Store
# Tienda Norte    686
# Tienda Este     657
# Tienda Sur      622
# Tienda Oeste    549
# Name: Quantity, dtype: int64

# %% [markdown]
# **Pregunta:** ¿Existen datos faltantes o duplicados?

# %%
# Tu código aquí
df_retail.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# Store               0
# dtype: int64

# %%
# Ver si hay filas duplicadas
df_retail.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Pregunta:** ¿Cuál es el ingreso total por tienda?

# %%
# Tu código aquí
df_retail.groupby('Store')['Total Amount'].sum().sort_values(ascending=False)
# Out:
# Store
# Tienda Norte    123655
# Tienda Este     118300
# Tienda Sur      116920
# Tienda Oeste     97125
# Name: Total Amount, dtype: int64

# %% [markdown]
# **Pregunta:** Agrupa las ventas por tipo de producto y encuentra la media de precios.

# %%
# Tu código aquí
df_retail.groupby('Product Category')['Price per Unit'].mean()
# Out:
# Product Category
# Beauty         184.055375
# Clothing       174.287749
# Electronics    181.900585
# Name: Price per Unit, dtype: float64

# %% [markdown]
# **Pregunta:** Crea una nueva columna llamada `ingreso_total` que sea precio * cantidad.

# %%
# Tu código aquí
df_retail['ingreso_total'] = df_retail['Price per Unit'] * df_retail['Quantity']

# %%
df_retail.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount         Store  ingreso_total
# 0         3              50           150  Tienda Norte            150
# 1         2             500          1000  Tienda Oeste           1000
# 2         1              30            30  Tienda Oeste             30
# 3         1             500           500  Tienda Oeste            500
# 4         2              50           100  Tienda Oeste            100

# %% [markdown]
# **Pregunta:** Usa una tabla dinámica para comparar ingresos por tienda y por producto.

# %%
# Tu código aquí
pd.pivot_table(df_retail, index='Store', columns='Product Category', values='ingreso_total', aggfunc='sum')
# Out:
# Product Category  Beauty  Clothing  Electronics
# Store
# Tienda Este        38035     39815        40450
# Tienda Norte       40110     40170        43375
# Tienda Oeste       30220     28865        38040
# Tienda Sur         35150     46730        35040

# %% [markdown]
# ## 📈 Dummy Advertising and Sales Data

# %% [markdown]
# 🔗 Dataset disponible en: [https://www.kaggle.com/datasets/harrimansaragih/dummy-advertising-and-sales-data?utm_source=chatgpt.com](https://www.kaggle.com/datasets/harrimansaragih/dummy-advertising-and-sales-data?utm_source=chatgpt.com)

# %%
dummy_df = pd.read_csv('./DataSets/Dummy Data HSS.csv')

# %%
dummy_df.head()
# Out:
#      TV      Radio  Social Media Influencer       Sales
# 0  16.0   6.566231      2.907983       Mega   54.732757
# 1  13.0   9.237765      2.409567       Mega   46.677897
# 2  41.0  15.886446      2.913410       Mega  150.177829
# 3  83.0  30.020028      6.922304       Mega  298.246340
# 4  15.0   8.437408      1.405998      Micro   56.594181

# %% [markdown]
# **Pregunta:** ¿Cuál es el gasto promedio en publicidad por canal (TV, Radio, Periódico)?

# %%
# Tu código aquí
dummy_df[['TV', 'Radio', 'Social Media']].mean()
# Out:
# TV              54.066857
# Radio           18.160356
# Social Media     3.323956
# dtype: float64

# %% [markdown]
# **Pregunta:** ¿Existe correlación entre el presupuesto publicitario y las ventas?

# %%
# Tu código aquí
dummy_df.corr(numeric_only=True)
# Out:
#                     TV     Radio  Social Media     Sales
# TV            1.000000  0.869460      0.528168  0.999497
# Radio         0.869460  1.000000      0.607452  0.869105
# Social Media  0.528168  0.607452      1.000000  0.528906
# Sales         0.999497  0.869105      0.528906  1.000000

# %% [markdown]
# **Pregunta:** ¿Qué campañas tienen ventas superiores a la media?

# %%
# Tu código aquí
ventas_media = dummy_df['Sales'].mean()
dummy_df[dummy_df['Sales'] > ventas_media]
# Out:
#         TV      Radio  Social Media Influencer       Sales
# 3     83.0  30.020028      6.922304       Mega  298.246340
# 6     55.0  24.893811      4.273602      Micro  198.679825
# 8     76.0  24.648898      7.130116      Macro  270.189400
# 10    62.0  24.345189      5.151483       Nano  224.961019
# 12    64.0  20.240424      3.921148      Micro  229.632381
# ...    ...        ...           ...        ...         ...
# 4561  60.0  21.841864      5.092528      Macro  210.680016
# 4563  93.0  25.285149      2.805840      Macro  327.466288
# 4564  99.0  36.024174      4.288755      Macro  355.807121
# 4568  71.0  20.610685      6.545573       Nano  249.101915
# 4570  71.0  17.534640      1.940873      Macro  253.610411
#
# [2239 rows x 5 columns]

# %%
ventas_media
# Out:
# np.float64(192.46660210662066)

# %% [markdown]
# **Pregunta:** Filtra las campañas con publicidad en TV > 200 y Radio > 20.

# %%
# Tu código aquí
dummy_df[(dummy_df['TV'] > 200) & (dummy_df['Radio'] > 20)]
# Out:
# Empty DataFrame
# Columns: [TV, Radio, Social Media, Influencer, Sales]
# Index: []

# %% [markdown]
# **Pregunta:** Agrupa por canal publicitario y calcula la media de ventas.

# %%
# Tu código aquí
dummy_df.groupby('Influencer')['Sales'].mean()
# Out:
# Influencer
# Macro    195.613601
# Mega     190.593666
# Micro    191.809095
# Nano     191.934304
# Name: Sales, dtype: float64

# %% [markdown]
# **Pregunta:** Crea una columna de ROI estimado usando una fórmula simple.

# %%
# Tu código aquí
dummy_df['ROI'] = dummy_df['Sales'] / (dummy_df['TV'] + dummy_df['Radio'] + dummy_df['Social Media'])
dummy_df.head()
# Out:
#      TV      Radio  Social Media Influencer       Sales       ROI
# 0  16.0   6.566231      2.907983       Mega   54.732757  2.148555
# 1  13.0   9.237765      2.409567       Mega   46.677897  1.893832
# 2  41.0  15.886446      2.913410       Mega  150.177829  2.511341
# 3  83.0  30.020028      6.922304       Mega  298.246340  2.486581
# 4  15.0   8.437408      1.405998      Micro   56.594181  2.278036

# %% [markdown]
# **Pregunta:** Realiza una pivot_table para ver ventas promedio por cada tipo de canal.

# %%
#ingreso total por tienda.
pd.pivot_table(dummy_df,index='Influencer',values=['TV', 'Radio', 'Social Media', 'Sales'],aggfunc='mean')
# Out:
#                 Radio       Sales  Social Media         TV
# Influencer
# Macro       18.321927  195.613601      3.369172  55.047449
# Mega        18.076145  190.593666      3.373669  53.500000
# Micro       18.230631  191.809095      3.273273  53.847958
# Nano        18.015812  191.934304      3.280347  53.901582

# %% [markdown]
# ## 🎬 The Movies Dataset

# %% [markdown]
# 🔗 Dataset disponible en: [https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset?utm_source=chatgpt.com](https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset?utm_source=chatgpt.com)

# %%
movies_df = pd.read_csv('./DataSets/MovieFranchises.csv')
movies_df.head(5)
# Out:
#    index MovieID                                           Title  \
# 0      0    1001              Star Wars: Episode IV - A New Hope
# 1      1    1002  Star Wars: Episode V - The Empire Strikes Back
# 2      2    1003      Star Wars: Episode VI - Return of the Jedi
# 3      3    1004                                   Jurassic Park
# 4      4    1005                   The Lost World: Jurassic Park
#
#   Lifetime Gross  Year              Studio Rating  Runtime      Budget  \
# 0      775398007  1977           Lucasfilm     PG    121.0  11000000.0
# 1      538375067  1980           Lucasfilm     PG    124.0  18000000.0
# 2      475106177  1983           Lucasfilm     PG    135.0  32500000.0
# 3     1109802321  1993  Universal Pictures  PG-13    127.0  63000000.0
# 4      618638999  1997  Universal Pictures  PG-13    129.0  73000000.0
#
#   ReleaseDate  VoteAvg  VoteCount  FranchiseID
# 0    05-25-77     4.09    96233.0        101.0
# 1    06-20-80     4.12    79231.0        101.0
# ...

# %% [markdown]
# **Pregunta:** ¿Cuáles son las películas con mayor presupuesto?

# %%
# Tu código aquí
movies_df.sort_values(by='Budget', ascending=False).head()
# Out:
#     index MovieID                                       Title Lifetime Gross  \
# 50     50    1051                           Avengers: Endgame     2797501328
# 43     43    1044     Star Wars: Episode VIII - The Last Jedi     1332698830
# 36     36    1037  Star Wars: Episode VII - The Force Awakens     2069521700
# 45     45    1046                      Avengers: Infinity War     2048359754
# 33     33    1034                     Avengers: Age of Ultron     1402809540
#
#     Year          Studio Rating  Runtime       Budget ReleaseDate  VoteAvg  \
# 50  2019  Marvel Studios  PG-13    181.0  400000000.0    04-26-19     3.91
# 43  2017       Lucasfilm  PG-13    152.0  317000000.0    12-15-17     3.31
# 36  2015       Lucasfilm  PG-13    136.0  306000000.0    12-18-15     3.65
# 45  2018  Marvel Studios  PG-13    156.0  300000000.0    04-27-18     3.93
# 33  2015  Marvel Studios  PG-13    141.0  280000000.0    04-22-15     3.50
#
#     VoteCount  FranchiseID
# ...

# %% [markdown]
# **Pregunta:** ¿Qué películas obtuvieron mayor ganancia (ingresos - presupuesto)?

# %%
# Tu código aquí
#movies_df['Profit'] = movies_df['Lifetime Gross'] - movies_df['Budget']
# Aqui el dato de Lifetime Gross lo tenemos qu transformar para poder usar el dato

# %%
movies_df.dtypes
# Out:
# index               int64
# MovieID            object
# Title              object
# Lifetime Gross     object
# Year               object
# Studio             object
# Rating             object
# Runtime           float64
# Budget            float64
# ReleaseDate        object
# VoteAvg           float64
# VoteCount         float64
# FranchiseID       float64
# dtype: object

# %%
# Transformar el tipo de dato de Lifetime Gross
movies_df['Lifetime Gross'] = pd.to_numeric(movies_df['Lifetime Gross'], errors='coerce')

# %%
movies_df.dtypes
# Out:
# index               int64
# MovieID            object
# Title              object
# Lifetime Gross    float64
# Year               object
# Studio             object
# Rating             object
# Runtime           float64
# Budget            float64
# ReleaseDate        object
# VoteAvg           float64
# VoteCount         float64
# FranchiseID       float64
# dtype: object

# %%
movies_df['Profit'] = movies_df['Lifetime Gross'] - movies_df['Budget']

# %%
# Mostrar las películas con mayor ganancia
top_5 = movies_df[['Title', 'Lifetime Gross', 'Budget', 'Profit']].sort_values(by='Profit', ascending=False).head(5)
top_5
# Out:
#                                          Title  Lifetime Gross       Budget  \
# 50                           Avengers: Endgame    2.797501e+09  400000000.0
# 36  Star Wars: Episode VII - The Force Awakens    2.069522e+09  306000000.0
# 45                      Avengers: Infinity War    2.048360e+09  300000000.0
# 56                     Spider-Man: No Way Home    1.915878e+09  200000000.0
# 34                              Jurassic World    1.671537e+09  150000000.0
#
#           Profit
# 50  2.397501e+09
# 36  1.763522e+09
# 45  1.748360e+09
# 56  1.715878e+09
# 34  1.521537e+09

# %% [markdown]
# **Pregunta:** ¿Cuántas películas hay por género?

# %%
# Tu código aquí
# No hay un genero en este DataSet solo que le lo agreguemos 
# Crear una nueva base
movies_genero_df = movies_df.copy()

# Asignar género aleatorio solo en la copia
generos = ['Action', 'Comedy', 'Drama', 'Fantasy', 'Sci-Fi', 'Animation', 'Adventure']
np.random.seed(42)
movies_genero_df['Genre'] = np.random.choice(generos, size=len(movies_genero_df))

# %%
peliculas_por_genero = movies_genero_df['Genre'].value_counts()
print(peliculas_por_genero)
# Out:
# Genre
# Fantasy      99
# Action       92
# Animation    89
# Adventure    88
# Comedy       81
# Sci-Fi       78
# Drama        78
# Name: count, dtype: int64

# %% [markdown]
# **Pregunta:** ¿Existen películas con presupuesto o ingresos nulos?

# %%
# Tu código aquí
peliculas_nulas = movies_df[(movies_df['Budget'].isnull()) | (movies_df['Budget'] == 0) |
                            (movies_df['Lifetime Gross'].isnull()) | (movies_df['Lifetime Gross'] == 0)]

# %%
peliculas_nulas[['Title', 'Budget', 'Lifetime Gross']]
# Out:
#                Title  Budget  Lifetime Gross
# 60           MovieID     NaN             NaN
# 61              1001     NaN             NaN
# 62              1001     NaN             NaN
# 63              1001     NaN             NaN
# 64              1001     NaN             NaN
# ..               ...     ...             ...
# 600        Star Wars     NaN          1977.0
# 601    Jurassic Park     NaN          1993.0
# 602  Wizarding World     NaN          2001.0
# 603     Middle Earth     NaN          2001.0
# 604              MCU     NaN          2008.0
#
# [545 rows x 3 columns]

# %% [markdown]
# **Pregunta:** Crea una nueva columna de rentabilidad (ganancia/presupuesto).

# %%
# Tu código aquí
# Como ya tenemos la columna  de Beneficio entonces solo necesitamos la de rentabilidad
movies_df['Rentabilidad'] = movies_df['Profit'] / movies_df['Budget']

# %%
movies_df[['Title', 'Profit', 'Budget', 'Rentabilidad']].head()
# Out:
#                                             Title        Profit      Budget  \
# 0              Star Wars: Episode IV - A New Hope  7.643980e+08  11000000.0
# 1  Star Wars: Episode V - The Empire Strikes Back  5.203751e+08  18000000.0
# 2      Star Wars: Episode VI - Return of the Jedi  4.426062e+08  32500000.0
# 3                                   Jurassic Park  1.046802e+09  63000000.0
# 4                   The Lost World: Jurassic Park  5.456390e+08  73000000.0
#
#    Rentabilidad
# 0     69.490728
# 1     28.909726
# 2     13.618652
# 3     16.615910
# 4      7.474507

# %% [markdown]
# **Pregunta:** Agrupa por año de lanzamiento y calcula ingresos promedio.

# %%
# Tu código aquí
ingresos_por_year = movies_df.groupby('Year')['Lifetime Gross'].mean()
ingresos_por_year
# Out:
# Year
# 1977                7.753980e+08
# 1980                5.383751e+08
# 1983                4.751062e+08
# 1993                1.109802e+09
# 1997                6.186390e+08
# 1999                1.027083e+09
# 2001                7.630552e+08
# 2002                8.272016e+08
# 2003                1.146436e+09
# 2004                7.976608e+08
# 2005                8.825604e+08
# 2007                9.422017e+08
# 2008                4.252836e+08
# 2009                9.344830e+08
# 2010                8.005019e+08
# 2011                7.207521e+08
# 2012                1.267923e+09
# 2013                9.395408e+08
# 2014                8.166577e+08
# 2015                1.415795e+09
# 2016                9.632719e+08
# 2017                9.826514e+08
# 2018                1.144405e+09
# 2019                1.533010e+09
# 2021                7.824844e+08
# 2022                9.040731e+08
# Creator                      NaN
# George Lucas        1.977000e+03
# ...

# %% [markdown]
# **Pregunta:** Realiza una tabla dinámica que compare ingresos por género y año.

# %%
movies_df['Year'] = pd.to_numeric(movies_df['Year'], errors='coerce')

# %%
pivot_genero_anio = pd.pivot_table(movies_genero_df,values='Lifetime Gross',index='Genre',columns='Year',aggfunc='sum')

pivot_genero_anio
# Out:
# Year              1977         1980         1983          1993         1997  \
# Genre
# Action             NaN          NaN          NaN           NaN          NaN
# Adventure  775398007.0          NaN          NaN  1.109802e+09          NaN
# Animation          NaN          NaN          NaN           NaN          NaN
# Comedy             NaN          NaN          NaN           NaN          NaN
# Drama              NaN          NaN          NaN           NaN  618638999.0
# Fantasy            NaN  538375067.0          NaN           NaN          NaN
# Sci-Fi             NaN          NaN  475106177.0           NaN          NaN
#
# Year               1999          2001          2002          2003  \
# Genre
# Action              NaN           NaN           NaN           NaN
# Adventure           NaN  1.022290e+09  8.799285e+08           NaN
# Animation           NaN           NaN           NaN           NaN
# Comedy              NaN  8.980947e+08           NaN           NaN
# ...

# %% [markdown]
# ## 🌦️ Climate Insights Dataset

# %% [markdown]
# 🔗 Dataset disponible en: [https://www.kaggle.com/datasets/goyaladi/climate-insights-dataset?utm_source=chatgpt.com](https://www.kaggle.com/datasets/goyaladi/climate-insights-dataset?utm_source=chatgpt.com)

# %%
df_clima = pd.read_csv('./DataSets/climate_change_data.csv')
df_clima.head()
# Out:
#                             Date          Location        Country  \
# 0  2000-01-01 00:00:00.000000000   New Williamtown         Latvia
# 1  2000-01-01 20:09:43.258325832      North Rachel   South Africa
# 2  2000-01-02 16:19:26.516651665  West Williamland  French Guiana
# 3  2000-01-03 12:29:09.774977497       South David        Vietnam
# 4  2000-01-04 08:38:53.033303330    New Scottburgh        Moldova
#
#    Temperature  CO2 Emissions  Sea Level Rise  Precipitation   Humidity  \
# 0    10.688986     403.118903        0.717506      13.835237  23.631256
# 1    13.814430     396.663499        1.205715      40.974084  43.982946
# 2    27.323718     451.553155       -0.160783      42.697931  96.652600
# 3    12.309581     422.404983       -0.475931       5.193341  47.467938
# 4    13.210885     410.472999        1.135757      78.695280  61.789672
#
#    Wind Speed
# 0   18.492026
# 1   34.249300
# 2   34.124261
# 3    8.554563
# 4    8.001164

# %%
df_clima.dtypes
# Out:
# Date               object
# Location           object
# Country            object
# Temperature       float64
# CO2 Emissions     float64
# Sea Level Rise    float64
# Precipitation     float64
# Humidity          float64
# Wind Speed        float64
# dtype: object

# %%
# Creamos una columna con los primeros 4 digitos de la columna date para hacer la columna year (años)
df_clima['Year'] = df_clima['Date'].str[:4]

# %%
df_clima
# Out:
#                                Date           Location                Country  \
# 0     2000-01-01 00:00:00.000000000    New Williamtown                 Latvia
# 1     2000-01-01 20:09:43.258325832       North Rachel           South Africa
# 2     2000-01-02 16:19:26.516651665   West Williamland          French Guiana
# 3     2000-01-03 12:29:09.774977497        South David                Vietnam
# 4     2000-01-04 08:38:53.033303330     New Scottburgh                Moldova
# ...                             ...                ...                    ...
# 9995  2022-12-27 15:21:06.966696576   South Elaineberg                 Bhutan
# 9996  2022-12-28 11:30:50.225022464       Leblancville                  Congo
# 9997  2022-12-29 07:40:33.483348224     West Stephanie              Argentina
# 9998  2022-12-30 03:50:16.741674112        Port Steven                Albania
# 9999  2022-12-31 00:00:00.000000000  West Anthonyburgh  Sao Tome and Principe
#
# ...

# %%
df_clima.dtypes
# Out:
# Date               object
# Location           object
# Country            object
# Temperature       float64
# CO2 Emissions     float64
# Sea Level Rise    float64
# Precipitation     float64
# Humidity          float64
# Wind Speed        float64
# Year               object
# dtype: object

# %% [markdown]
# **Pregunta:** ¿Cuántos registros hay por año?

# %%
# Tu código aquí

df_clima['Year'].value_counts().sort_index()
# Out:
# Year
# 2000    436
# 2001    435
# 2002    434
# 2003    435
# 2004    435
# 2005    435
# 2006    434
# 2007    435
# 2008    435
# 2009    435
# 2010    434
# 2011    435
# 2012    436
# 2013    434
# 2014    434
# 2015    435
# 2016    436
# 2017    434
# 2018    435
# 2019    434
# 2020    436
# 2021    434
# 2022    434
# Name: count, dtype: int64

# %% [markdown]
# **Pregunta:** ¿Cuál es la temperatura media mensual más alta y más baja?

# %%
#Creamos una columna con los datos del mes
df_clima['Month'] = df_clima['Date'].str[5:7]

# %%
df_clima.head(1)
# Out:
#                             Date         Location Country  Temperature  \
# 0  2000-01-01 00:00:00.000000000  New Williamtown  Latvia    10.688986
#
#    CO2 Emissions  Sea Level Rise  Precipitation   Humidity  Wind Speed  Year  \
# 0     403.118903        0.717506      13.835237  23.631256   18.492026  2000
#
#   Month
# 0    01

# %%
# Tu código aquí
temperatura_media_mensual = df_clima.groupby('Month')['Temperature'].mean()

temperatura_media_mensual = temperatura_media_mensual.sort_values(ascending=False)

temperatura_media_mensual
# Out:
# Month
# 11    15.290563
# 02    15.165099
# 07    15.012949
# 08    14.968462
# 06    14.941632
# 09    14.913659
# 12    14.907306
# 03    14.859202
# 05    14.822854
# 01    14.817508
# 10    14.813730
# 04    14.745375
# Name: Temperature, dtype: float64

# %% [markdown]
# **Pregunta:** ¿Qué meses tienen mayor precipitación?

# %%
# Tu código aquí
precip_mensual = df_clima.groupby('Month')['Precipitation'].mean().sort_values(ascending=False)
precip_mensual.head(10)
# Out:
# Month
# 09    50.947790
# 05    50.818566
# 03    50.494378
# 10    50.241029
# 04    50.131147
# 06    50.130129
# 12    50.059991
# 11    49.900964
# 02    49.550014
# 01    49.380073
# Name: Precipitation, dtype: float64

# %% [markdown]
# **Pregunta:** ¿Existen valores faltantes en alguna columna?

# %%
# Tu código aquí
df_clima.isnull().sum()
# Out:
# Date              0
# Location          0
# Country           0
# Temperature       0
# CO2 Emissions     0
# Sea Level Rise    0
# Precipitation     0
# Humidity          0
# Wind Speed        0
# Year              0
# Month             0
# dtype: int64

# %% [markdown]
# **Pregunta:** Agrupa por estación del año y calcula la media de temperatura.

# %%
df_clima.head()
# Out:
#                             Date          Location        Country  \
# 0  2000-01-01 00:00:00.000000000   New Williamtown         Latvia
# 1  2000-01-01 20:09:43.258325832      North Rachel   South Africa
# 2  2000-01-02 16:19:26.516651665  West Williamland  French Guiana
# 3  2000-01-03 12:29:09.774977497       South David        Vietnam
# 4  2000-01-04 08:38:53.033303330    New Scottburgh        Moldova
#
#    Temperature  CO2 Emissions  Sea Level Rise  Precipitation   Humidity  \
# 0    10.688986     403.118903        0.717506      13.835237  23.631256
# 1    13.814430     396.663499        1.205715      40.974084  43.982946
# 2    27.323718     451.553155       -0.160783      42.697931  96.652600
# 3    12.309581     422.404983       -0.475931       5.193341  47.467938
# 4    13.210885     410.472999        1.135757      78.695280  61.789672
#
#    Wind Speed  Year  Month  Estacion     Clima
# 0   18.492026  2000      1  Invierno  templado
# ...

# %%
# Tu código aquí
df_clima['Month'] = df_clima['Month'].astype(int)

mes_estacion = {
    12: 'Invierno', 1: 'Invierno', 2: 'Invierno',
    3: 'Primavera', 4: 'Primavera', 5: 'Primavera',
    6: 'Verano', 7: 'Verano', 8: 'Verano',
    9: 'Otoño', 10: 'Otoño', 11: 'Otoño'
}

df_clima['Estacion'] = df_clima['Month'].replace(mes_estacion)

media_temp_estacion = df_clima.groupby('Estacion')['Temperature'].mean()
print(media_temp_estacion)
# Out:
# Estacion
# Invierno     14.957014
# Otoño        15.003823
# Primavera    14.809827
# Verano       14.974683
# Name: Temperature, dtype: float64

# %%
df_clima.head(0)
# Out:
# Empty DataFrame
# Columns: [Date, Location, Country, Temperature, CO2 Emissions, Sea Level Rise, Precipitation, Humidity, Wind Speed, Year, Month, Estacion, Clima]
# Index: []

# %% [markdown]
# **Pregunta:** Crea una columna que clasifique los días como 'calurosos' o 'templados'.

# %%
# Tu código aquí
df_clima['Clima'] = 'templado'

df_clima.loc[df_clima['Temperature'] >= 26, 'Clima'] = 'caluroso'

df_clima[['Date','Temperature','Clima']].head()
# Out:
#                             Date  Temperature     Clima
# 0  2000-01-01 00:00:00.000000000    10.688986  templado
# 1  2000-01-01 20:09:43.258325832    13.814430  templado
# 2  2000-01-02 16:19:26.516651665    27.323718  caluroso
# 3  2000-01-03 12:29:09.774977497    12.309581  templado
# 4  2000-01-04 08:38:53.033303330    13.210885  templado

# %% [markdown]
# **Pregunta:** Genera una pivot_table que muestre la temperatura promedio por año y mes.

# %%
# Tu código aquí

temp_year_month = pd.pivot_table(df_clima,values='Temperature',index='Year',columns='Month',aggfunc='mean')

temp_year_month
# Out:
# Month         1          2          3          4          5          6   \
# Year
# 2000   14.206357  13.932424  16.353462  14.956865  15.447593  15.312805
# 2001   14.708201  16.514600  13.973159  15.036136  14.800959  14.723588
# 2002   13.620897  14.760417  14.212325  13.850515  13.673576  13.502537
# 2003   14.885562  16.854469  14.114849  14.987196  14.129527  14.842865
# 2004   15.914895  13.717340  14.815031  15.814182  15.283723  15.279225
# 2005   15.310610  14.956032  16.763042  14.461071  16.430089  15.204628
# 2006   13.021321  14.050059  16.181762  14.232334  15.479402  16.405412
# 2007   14.419660  14.287890  14.973328  13.083154  15.425498  16.270065
# 2008   15.947948  15.317924  14.456524  14.146105  15.636002  15.028988
# 2009   15.004275  13.500589  14.986215  13.581644  13.945644  14.644463
# 2010   16.430713  16.602293  13.796567  14.304352  14.307113  14.671207
# 2011   14.799867  13.479437  15.693903  15.139654  14.684203  15.105863
# ...
